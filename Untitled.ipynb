# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from tl_hidden.tl_model import load_module
from tl_hidden.tl_inference import extract_hidden_features_from_disk
from tl_hidden.utils import list_all_images

import pickle
# Out:
# /home/ubuntu/anaconda3/envs/tensorflow_p36/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
input_tensor, output_tensor, image_shape = load_module()
# Out:
# INFO:tensorflow:Using /tmp/tfhub_modules to cache modules.
# INFO:tensorflow:Initialize variable module/InceptionV3/Conv2d_1a_3x3/BatchNorm/beta:0 from checkpoint b'/tmp/tfhub_modules/11d9faf945d073033780fd924b2b09ff42155763/variables/variables' with InceptionV3/Conv2d_1a_3x3/BatchNorm/beta
# INFO:tensorflow:Initialize variable module/InceptionV3/Conv2d_1a_3x3/BatchNorm/moving_mean:0 from checkpoint b'/tmp/tfhub_modules/11d9faf945d073033780fd924b2b09ff42155763/variables/variables' with InceptionV3/Conv2d_1a_3x3/BatchNorm/moving_mean
# INFO:tensorflow:Initialize variable module/InceptionV3/Conv2d_1a_3x3/BatchNorm/moving_variance:0 from checkpoint b'/tmp/tfhub_modules/11d9faf945d073033780fd924b2b09ff42155763/variables/variables' with InceptionV3/Conv2d_1a_3x3/BatchNorm/moving_variance
# ...

# %%
PATH = '/home/ubuntu/Projects/FashionRecommender/data/baseline/images/'

# %%
list_images = list_all_images(PATH)

# %%
hidden_features, image_names = extract_hidden_features_from_disk(input_tensor,
                                                                 output_tensor,
                                                                 image_shape,
                                                                 list_images,
                                                                 path = PATH,
                                                                 batch_img_size = 1024,
                                                                 batch_tf_size = 256,
                                                                 padding = True
                                                                )
# Out:
# Batch images:0
# (1024, 299, 299, 3)
# Batch tensorflow:0
# Batch tensorflow:1
# Batch tensorflow:2
# Batch tensorflow:3
# Batch tensorflow:4
# Batch images:1
# (1024, 299, 299, 3)
# Batch tensorflow:0
# Batch tensorflow:1
# Batch tensorflow:2
# Batch tensorflow:3
# Batch tensorflow:4
# Batch images:2
# (1024, 299, 299, 3)
# Batch tensorflow:0
# Batch tensorflow:1
# Batch tensorflow:2
# Batch tensorflow:3
# Batch tensorflow:4
# Batch images:3
# (1024, 299, 299, 3)
# Batch tensorflow:0
# Batch tensorflow:1
# Batch tensorflow:2
# Batch tensorflow:3
# Batch tensorflow:4
# Batch images:4
# (1024, 299, 299, 3)
# Batch tensorflow:0
# Batch tensorflow:1
# Batch tensorflow:2
# Batch tensorflow:3
# Batch tensorflow:4
# Batch images:5
# (1024, 299, 299, 3)
# Batch tensorflow:0
# Batch tensorflow:1
# Batch tensorflow:2
# Batch tensorflow:3
# Batch tensorflow:4
# Batch images:6
# (1024, 299, 299, 3)
# Batch tensorflow:0
# Batch tensorflow:1
# Batch tensorflow:2
# Batch tensorflow:3
# ...

# %%
print(hidden_features.shape, len(image_names))
# Out:
# (61862, 2048) 61862

# %%
with open('hidden_features.pickle', 'wb') as handle:
    pickle.dump(hidden_features, handle, protocol=pickle.HIGHEST_PROTOCOL)
with open('image_names.pickle', 'wb') as handle:
    pickle.dump(image_names, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
from sklearn.neighbors import NearestNeighbors

# %%
classifier = NearestNeighbors(n_neighbors=10)  
classifier.fit(hidden_features)
# Out:
# NearestNeighbors(algorithm='auto', leaf_size=30, metric='minkowski',
#          metric_params=None, n_jobs=1, n_neighbors=10, p=2, radius=1.0)

# %%
y_pred = classifier.kneighbors(hidden_features[0:4], return_distance=False)

# %%
y_pred
# Out:
# array([[    0, 30790, 15109,  7822, 36367, 30345, 30593, 33730, 36296,
#         30597],
#        [    1, 42302, 25393, 42937, 24036, 43511, 34905, 11894, 21653,
#         27797],
#        [32834, 49289, 41167,     2,  9997, 43737,  5211, 39145, 54956,
#         48043],
#        [48389,     3,  4815, 23560,  1803, 41609, 35582, 20194, 50619,
#         29859]])

# %%
from tl_hidden.utils import load_images

# %%
images_batch = load_images(PATH, list_images[0:1000], image_shape = image_shape, padding = True)

# %%
images_batch.shape
# Out:
# (1000, 299, 299, 3)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.imshow(a[8])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f14a7f5ebfd2> in <module>()
# ----> 1 plt.imshow(a[8])
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import numpy as np

# %%
np.asarray([])
# Out:
# array([], dtype=float64)
